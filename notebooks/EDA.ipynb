# %% [markdown]
# 1: Load the Data

# %%
import sys
import os
import numpy as np
import pandas as pd
import sidetable
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Add the path to the scripts directory
sys.path.append(os.path.abspath('../scripts'))

# Import the EDA class from EDA moudle
from EDA import EDA

# Load the data
data_path = '../src/Data/data.csv'
df = pd.read_csv(data_path)

# Display the first few rows of the dataset
df.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
# ...

# %% [markdown]
# 2: Overview of the Data

# %%
# Create an instance of the EDA class
eda = EDA(df)

# Overview of the Data
shape, dtypes, missing_values = eda.overview_of_data()
# Out:
# ### Overview of Data ###
# Number of Rows: 95662
# Number of Columns: 16
#
# Data Types:
#  TransactionId            object
# BatchId                  object
# AccountId                object
# SubscriptionId           object
# CustomerId               object
# CurrencyCode             object
# CountryCode               int64
# ProviderId               object
# ProductId                object
# ProductCategory          object
# ChannelId                object
# Amount                  float64
# Value                     int64
# TransactionStartTime     object
# PricingStrategy           int64
# FraudResult               int64
# dtype: object
#
# Missing Values:
#  TransactionId           0
# BatchId                 0
# AccountId               0
# SubscriptionId          0
# CustomerId              0
# CurrencyCode            0
# CountryCode             0
# ProviderId              0
# ProductId               0
# ProductCategory         0
# ChannelId               0
# ...

# %% [markdown]
# 3: Summary Statistics

# %%
# Summary Statistics
numerical_summary, categorical_summary = eda.summary_statistics()

# Displaying in tabular format
print("Numerical Summary Statistics:")
print(pd.DataFrame(numerical_summary))

print("\nCategorical Summary Statistics:")
print(pd.DataFrame(categorical_summary))
# Out:
# ### Summary Statistics for Numerical Data ###
#        CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
# mean         256.0  6.717846e+03  9.900584e+03         2.255974      0.002018
# std            0.0  1.233068e+05  1.231221e+05         0.732924      0.044872
# min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
# 25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
# 50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
# 75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
# max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000
#
# ### Summary Statistics for Categorical Data ###
#               TransactionId        BatchId       AccountId  \
# count                 95662          95662           95662
# ...

# %% [markdown]
# 3: Summary Statistics

# %%
# Summary Statistics
numerical_summary, categorical_summary = eda.summary_statistics()

# Displaying in tabular format
print("Numerical Summary Statistics:")
print(pd.DataFrame(numerical_summary))

print("\nCategorical Summary Statistics:")
print(pd.DataFrame(categorical_summary))
# Out:
# ### Summary Statistics for Numerical Data ###
#        CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
# mean         256.0  6.717846e+03  9.900584e+03         2.255974      0.002018
# std            0.0  1.233068e+05  1.231221e+05         0.732924      0.044872
# min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
# 25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
# 50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
# 75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
# max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000
#
# ### Summary Statistics for Categorical Data ###
#               TransactionId        BatchId       AccountId  \
# count                 95662          95662           95662
# ...

# %% [markdown]
# 4: Count Unique Values for Each Column

# %%
# Count unique values for each column
unique_counts = eda.count_unique_values()
# Out:
# Unique values in TransactionId: 95662
# Unique values in BatchId: 94809
# Unique values in AccountId: 3633
# Unique values in SubscriptionId: 3627
# Unique values in CustomerId: 3742
# Unique values in CurrencyCode: 1
# Unique values in CountryCode: 1
# Unique values in ProviderId: 6
# Unique values in ProductId: 23
# Unique values in ProductCategory: 9
# Unique values in ChannelId: 4
# Unique values in Amount: 1676
# Unique values in Value: 1517
# Unique values in TransactionStartTime: 94556
# Unique values in PricingStrategy: 4
# Unique values in FraudResult: 2

# %% [markdown]
# 5: Find Unique Values for Specific Columns

# %%
# Columns to find unique values for
columns = ['CurrencyCode', 'CountryCode', 'ChannelId', 'ProviderId', 'PricingStrategy', 'FraudResult', 'ProductId', 'ProductCategory']
unique_values = eda.find_unique_values(columns)
# Out:
# Unique values in CurrencyCode: ['UGX']
#
# Unique values in CountryCode: [256]
#
# Unique values in ChannelId: ['ChannelId_3' 'ChannelId_2' 'ChannelId_1' 'ChannelId_5']
#
# Unique values in ProviderId: ['ProviderId_6' 'ProviderId_4' 'ProviderId_1' 'ProviderId_5'
#  'ProviderId_3' 'ProviderId_2']
#
# Unique values in PricingStrategy: [2 4 1 0]
#
# Unique values in FraudResult: [0 1]
#
# Unique values in ProductId: ['ProductId_10' 'ProductId_6' 'ProductId_1' 'ProductId_21' 'ProductId_3'
#  'ProductId_15' 'ProductId_11' 'ProductId_19' 'ProductId_4' 'ProductId_5'
#  'ProductId_20' 'ProductId_9' 'ProductId_24' 'ProductId_14' 'ProductId_2'
#  'ProductId_13' 'ProductId_22' 'ProductId_8' 'ProductId_7' 'ProductId_27'
#  'ProductId_12' 'ProductId_16' 'ProductId_23']
#
# Unique values in ProductCategory: ['airtime' 'financial_services' 'utility_bill' 'data_bundles' 'tv'
#  'transport' 'ticket' 'movies' 'other']

# %% [markdown]
# 6: Plot Numerical Features

# %%
# Plot numerical features
eda.plot_numerical_features()
# Out:
# e:\OnlineClass\AIM\Bati-Bank-Credit-Score-Modelling\scripts\EDA.py:74: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=feature, palette='pastel', ax=axs[row, col])
# e:\OnlineClass\AIM\Bati-Bank-Credit-Score-Modelling\scripts\EDA.py:74: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=feature, palette='pastel', ax=axs[row, col])
# e:\OnlineClass\AIM\Bati-Bank-Credit-Score-Modelling\scripts\EDA.py:74: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# 7: Plot Categorical Features

# %%
# Plot categorical features
eda.plot_categorical_features()
# Out:
# e:\OnlineClass\AIM\Bati-Bank-Credit-Score-Modelling\scripts\EDA.py:99: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=feature, palette='pastel', ax=axs[row, col])
# e:\OnlineClass\AIM\Bati-Bank-Credit-Score-Modelling\scripts\EDA.py:99: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=feature, palette='pastel', ax=axs[row, col])
# e:\OnlineClass\AIM\Bati-Bank-Credit-Score-Modelling\scripts\EDA.py:99: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# 8: Correlation Analysis

# %%
# Correlation Analysis
correlation_matrix = eda.correlation_analysis()
# Out:
# ### Correlation Analysis ###
#
# Correlation Matrix:
#                  CountryCode    Amount     Value  PricingStrategy  FraudResult
# CountryCode              NaN       NaN       NaN              NaN          NaN
# Amount                   NaN  1.000000  0.989692        -0.061931     0.557370
# Value                    NaN  0.989692  1.000000        -0.017020     0.566739
# PricingStrategy          NaN -0.061931 -0.017020         1.000000    -0.033821
# FraudResult              NaN  0.557370  0.566739        -0.033821     1.000000

# %% [markdown]
# 9: Identifying Missing Values

# %%
# Identifying Missing Values
missing_values = eda.identify_missing_values()
# Out:
# ### Missing Values ###
# Series([], dtype: int64)

# %% [markdown]
# 10: Outlier Detection with Visualization

# %%
# Outlier Detection with Visualization
outliers_dict = eda.detect_outliers_with_visualization()
# Out:
# 0 outliers detected in CountryCode using IQR method.
# 24441 outliers detected in Amount using IQR method.
# 9021 outliers detected in Value using IQR method.
# 15814 outliers detected in PricingStrategy using IQR method.
# 193 outliers detected in FraudResult using IQR method.
