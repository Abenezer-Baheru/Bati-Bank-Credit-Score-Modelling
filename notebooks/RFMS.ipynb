# %% [markdown]
# 1: Load the Data

# %%
import sys
import os

# Add the path to the scripts directory
sys.path.append(os.path.abspath('../scripts'))

# Import the RFMS class from RFMS moudle
from RFMS import RFMS

# Initialize the RFMS class with the data path
data_path = '../src/data/featured.csv'
rfms = RFMS(data_path)
# Out:
# Data loaded successfully.

# %% [markdown]
# 2: Calculate RFMS Features

# %%
# Calculate RFMS Features
rfms.calculate_rfms_features()
# Out:
# RFMS features calculated successfully.
#               TransactionId         BatchId       AccountId  \
# 0       TransactionId_76871   BatchId_36123  AccountId_3957
# 1       TransactionId_73770   BatchId_15642  AccountId_4841
# 2       TransactionId_26203   BatchId_53941  AccountId_4229
# 3         TransactionId_380  BatchId_102363   AccountId_648
# 4       TransactionId_28195   BatchId_38780  AccountId_4841
# ...                     ...             ...             ...
# 94945   TransactionId_89881   BatchId_96668  AccountId_4841
# 94946   TransactionId_91597    BatchId_3503  AccountId_3439
# 94947   TransactionId_82501  BatchId_118602  AccountId_4841
# 94948  TransactionId_136354   BatchId_70924  AccountId_1346
# 94949   TransactionId_35670   BatchId_29317  AccountId_4841
#
#             SubscriptionId       CustomerId  CurrencyCode  CountryCode  \
# 0       SubscriptionId_887  CustomerId_4406             0          256
# ...

# %% [markdown]
# 3: Check the distribution of numerical features

# %%
# Check the distribution of numerical features
rfms.check_distribution()
# Out:
# Distribution check completed successfully.

# %% [markdown]
# 4: Visualize RFMS Space

# %%
# Visualize RFMS space
rfms.visualize_rfms()
# Out:
# RFMS visualization completed successfully.

# %% [markdown]
# 5: Establish a Boundary and Assign Labels

# %%
# Assign labels
rfms.assign_labels(threshold=0.5)
# Out:
# Labels assigned successfully.
#               TransactionId         BatchId       AccountId  \
# 0       TransactionId_76871   BatchId_36123  AccountId_3957
# 1       TransactionId_73770   BatchId_15642  AccountId_4841
# 2       TransactionId_26203   BatchId_53941  AccountId_4229
# 3         TransactionId_380  BatchId_102363   AccountId_648
# 4       TransactionId_28195   BatchId_38780  AccountId_4841
# ...                     ...             ...             ...
# 94945   TransactionId_89881   BatchId_96668  AccountId_4841
# 94946   TransactionId_91597    BatchId_3503  AccountId_3439
# 94947   TransactionId_82501  BatchId_118602  AccountId_4841
# 94948  TransactionId_136354   BatchId_70924  AccountId_1346
# 94949   TransactionId_35670   BatchId_29317  AccountId_4841
#
#             SubscriptionId       CustomerId  CurrencyCode  CountryCode  \
# 0       SubscriptionId_887  CustomerId_4406             0          256
# ...

# %% [markdown]
# 6: Plot the labels in a bar graph

# %%
# Plot the labels in a bar graph
rfms.plot_labels()
# Out:
# e:\OnlineClass\AIM\Bati-Bank-Credit-Score-Modelling\scripts\RFMS.py:85: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x='Label', palette='coolwarm')
# Label plot completed successfully.

# %% [markdown]
# 7: Save the Transformed Data

# %%
# Save the RFMS data to a file
rfms_data_path = '../src/data/rfms.csv'
rfms.save_rfms_data(rfms_data_path)
# Out:
# RFMS data saved to ../src/data/rfms.csv
